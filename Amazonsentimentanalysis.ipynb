# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("Databaseforml/amazonreview.csv")
# Out:
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\3219666551.py:5: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Databaseforml/amazonreview.csv")

# %%
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 3  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 4  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#                reviews.date     reviews.dateAdded  \
# 0  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 1  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 2  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 3  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 4  2017-01-12T00:00:00.000Z  2017-07-03T23:33:15Z
#
#                                     reviews.dateSeen  ... reviews.doRecommend  \
# 0  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 1  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 2  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 3  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 4  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
#
#   reviews.id  reviews.numHelpful  reviews.rating  \
# 0        NaN                 0.0             5.0
# 1        NaN                 0.0             5.0
# 2        NaN                 0.0             5.0
# 3        NaN                 0.0             4.0
# 4        NaN                 0.0             5.0
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5620406/review...
# 1  http://reviews.bestbuy.com/3545/5620406/review...
# 2  http://reviews.bestbuy.com/3545/5620406/review...
# 3  http://reviews.bestbuy.com/3545/5620406/review...
# 4  http://reviews.bestbuy.com/3545/5620406/review...
#
#                                         reviews.text  \
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...
#
#                              reviews.title reviews.userCity  \
# 0                                   Kindle              NaN
# 1                                very fast              NaN
# 2  Beginner tablet for our 9 year old son.              NaN
# 3                                  Good!!!              NaN
# 4                Fantastic Tablet for kids              NaN
#
#    reviews.userProvince  reviews.username
# 0                   NaN           Adapter
# 1                   NaN            truman
# 2                   NaN             DaveZ
# 3                   NaN            Shacks
# 4                   NaN         explore42
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# id                          0
# name                     6760
# asins                       2
# brand                       0
# categories                  0
# keys                        0
# manufacturer                0
# reviews.date               39
# reviews.dateAdded       10621
# reviews.dateSeen            0
# reviews.didPurchase     34659
# reviews.doRecommend       594
# reviews.id              34659
# reviews.numHelpful        529
# reviews.rating             33
# reviews.sourceURLs          0
# reviews.text                1
# reviews.title               5
# reviews.userCity        34660
# reviews.userProvince    34660
# reviews.username            2
# dtype: int64

# %%
df = df.drop(['id','asins','reviews.sourceURLs','reviews.id','reviews.userCity','reviews.userProvince','reviews.date','reviews.dateAdded','reviews.dateSeen','reviews.didPurchase'],axis = 1)
df.head()
# Out:
#                                                 name   brand  \
# 0  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 1  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 2  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 3  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 4  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
#
#                                           categories  \
# 0  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 3  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 4  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#   reviews.doRecommend  reviews.numHelpful  reviews.rating  \
# 0                True                 0.0             5.0
# 1                True                 0.0             5.0
# 2                True                 0.0             5.0
# 3                True                 0.0             4.0
# 4                True                 0.0             5.0
#
#                                         reviews.text  \
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...
#
#                              reviews.title reviews.username
# 0                                   Kindle          Adapter
# 1                                very fast           truman
# 2  Beginner tablet for our 9 year old son.            DaveZ
# 3                                  Good!!!           Shacks
# 4                Fantastic Tablet for kids        explore42

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34660 entries, 0 to 34659
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 27900 non-null  object
#  1   brand                34660 non-null  object
#  2   categories           34660 non-null  object
#  3   keys                 34660 non-null  object
#  4   manufacturer         34660 non-null  object
#  5   reviews.doRecommend  34066 non-null  object
#  6   reviews.numHelpful   34131 non-null  float64
#  7   reviews.rating       34627 non-null  float64
#  8   reviews.text         34659 non-null  object
#  9   reviews.title        34655 non-null  object
#  10  reviews.username     34658 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 2.9+ MB

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pandh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df["review"] = df["reviews.text"].str.replace('<br />','', regex=True)
df['review']
# Out:
# 0        This product so far has not disappointed. My c...
# 1        great for beginner or experienced person. Boug...
# 2        Inexpensive tablet for him to use and learn on...
# 3        I've had my Fire HD 8 two weeks now and I love...
# 4        I bought this for my grand daughter when she c...
#                                ...
# 34655    This is not appreciably faster than any other ...
# 34656    Amazon should include this charger with the Ki...
# 34657    Love my Kindle Fire but I am really disappoint...
# 34658    I was surprised to find it did not come with a...
# 34659    to spite the fact that i have nothing but good...
# Name: review, Length: 34660, dtype: object

# %%
import contractions
df.rename(columns={"reviews.text":"reviews","reviews.rating":"sentiment","reviews.title":"title"},inplace=True)

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

good_reviews=df[df['sentiment']>=4]['reviews']
bad_reviews=df[df['sentiment']<=2]['reviews']
neutral_reviews = df[df['sentiment']==3]['reviews']
print("First 10 samples of good reviews\n".format(),good_reviews[:5])
print("First 10 samples of bad reviews\n".format(),bad_reviews[:10])
print("First 10 samples of neutral reviews\n".format(),neutral_reviews[:10])
# Out:
# First 10 samples of good reviews
#  0    This product so far has not disappointed. My c...
# 1    great for beginner or experienced person. Boug...
# 2    Inexpensive tablet for him to use and learn on...
# 3    I've had my Fire HD 8 two weeks now and I love...
# 4    I bought this for my grand daughter when she c...
# Name: reviews, dtype: object
# First 10 samples of bad reviews
#  117    Didn't have some of the features I was looking...
# 126    i Bought this around black friday for $60 hopi...
# 169    I bought this tablet for my 4 year old daughte...
# 241    Didn't want to go to the sites amazon wanted m...
# 281    Not a good product short battery life i can on...
# 297    This Kindle is so overloaded with apps that I ...
# 310    I liked it at first except the browser is kind...
# 338    If ads dont bother you, then this may be a dec...
# 444    If you shop on Amazon all the time, this will ...
# 446    fire tablet is very powerful for the size and ...
# Name: reviews, dtype: object
# First 10 samples of neutral reviews
#  222    I was hoping to use Google launcher with this ...
# 226    The tablet works fine. It is responsive with g...
# 298    Fine for reading, ...haven't used it for anyth...
# 354    Though I have got it for cheap price during bl...
# 371    This is a good product for video, surfing and ...
# 421    The display is not as sharp and vivid as they ...
# 431    Good starter unit. Easy for a beginner to use....
# 526    Much harder to work than an android. None of t...
# 536    I had fire hdx 8 and loved it, unfortunately g...
# 542    The Amazon Fire HD8 (2016 model) is a great ta...
# Name: reviews, dtype: object

# %%
count_good=df[df['sentiment'] >3]

count_bad=df[df['sentiment']<=3]

# %%
count_bad=count_bad[["reviews","sentiment"]]

# %%
count_good=count_good[["reviews","sentiment"]]
count_good.reviews
count_good.reset_index(inplace=True,drop=True)
count_bad.reset_index(inplace=True,drop=True)

# %%
count_bad
# Out:
#                                                 reviews  sentiment
# 0     Didn't have some of the features I was looking...        2.0
# 1     i Bought this around black friday for $60 hopi...        1.0
# 2     I bought this tablet for my 4 year old daughte...        1.0
# 3     I was hoping to use Google launcher with this ...        3.0
# 4     The tablet works fine. It is responsive with g...        3.0
# ...                                                 ...        ...
# 2306  This is not appreciably faster than any other ...        3.0
# 2307  Amazon should include this charger with the Ki...        1.0
# 2308  Love my Kindle Fire but I am really disappoint...        1.0
# 2309  I was surprised to find it did not come with a...        1.0
# 2310  to spite the fact that i have nothing but good...        1.0
#
# [2311 rows x 2 columns]

# %%
count_good
# Out:
#                                                  reviews  sentiment
# 0      This product so far has not disappointed. My c...        5.0
# 1      great for beginner or experienced person. Boug...        5.0
# 2      Inexpensive tablet for him to use and learn on...        5.0
# 3      I've had my Fire HD 8 two weeks now and I love...        4.0
# 4      I bought this for my grand daughter when she c...        5.0
# ...                                                  ...        ...
# 32311  I have only used it one time to download an e-...        5.0
# 32312  Excellent charging quality with heavy duty cor...        5.0
# 32313  This charger (9W) rapid charger is as describe...        5.0
# 32314  just what i expected and just what I wanted. t...        5.0
# 32315                                   Connects snugly!        5.0
#
# [32316 rows x 2 columns]

# %%
import seaborn as sns
#Analyse the count of words in each segment- both positive and negative reviews
#Function for checking word length
def cal_len(data):
    return len(data)

#Create generic plotter with Seaborn
def plot_count(count_ones,count_zeros,title_1,title_2,subtitle):
    fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,5))
    sns.distplot(count_zeros,ax=ax1,color='Blue')
    ax1.set_title(title_1)
    sns.distplot(count_ones,ax=ax2,color='Red')
    ax2.set_title(title_2)
    fig.suptitle(subtitle)
    plt.show()    




count_good_words=count_good['reviews'].str.split().apply(lambda z:cal_len(str(z)))
count_bad_words=count_bad['reviews'].str.split().apply(lambda z:cal_len(str(z)))
print("Positive Review Words:" + str(count_good_words))
print("Negative Review Words:" + str(count_bad_words))
plot_count(count_good_words,count_bad_words,"Positive Review","Negative Review","Reviews Word Analysis")
# Out:
# Positive Review Words:0        225
# 1        118
# 2        210
# 3        945
# 4        965
#         ...
# 32311    273
# 32312    151
# 32313    344
# 32314     83
# 32315     23
# Name: reviews, Length: 32316, dtype: int64
# Negative Review Words:0        161
# 1       1714
# 2        196
# 3        278
# 4        346
#         ...
# 2306    1726
# 2307     388
# 2308     495
# 2309     370
# 2310     742
# Name: reviews, Length: 2311, dtype: int64
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\3483694784.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(count_zeros,ax=ax1,color='Blue')
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\3483694784.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(count_ones,ax=ax2,color='Red')

# %%
def plot_count_1(count_ones,count_zeros,title_1,title_2,subtitle):
    fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,5))
    sns.distplot(count_zeros,ax=ax1,color='Blue')
    ax1.set_title(title_1)
    sns.distplot(count_ones,ax=ax2,color='Orange')
    ax2.set_title(title_2)
    fig.suptitle(subtitle)
    plt.show()    


stops=set(stopwords.words('english'))
count_good_stops=df['reviews'].apply(lambda z : np.mean([len(w) for w in str(z).split()]))
count_bad_stops=df['reviews'].apply(lambda z : np.mean([len(w) for w in str(z).split()]))
plot_count_1(count_good_stops,count_bad_stops,"Positive Reviews Stopwords","Negative Reviews Stopwords","Reviews Stopwords Analysis")
# Out:
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\1937842124.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(count_zeros,ax=ax1,color='Blue')
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\1937842124.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(count_ones,ax=ax2,color='Orange')

# %%
import string
count_good_punctuations=count_good['reviews'].apply(lambda z: len([c for c in str(z) if c in string.punctuation]))
count_bad_punctuations=count_bad['reviews'].apply(lambda z:len([c for c in str(z) if c in string.punctuation]))
plot_count(count_good_punctuations,count_bad_punctuations,"Positive Review Punctuations","Negative Review Punctuations","Reviews Word Punctuation Analysis")
# Out:
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\3483694784.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(count_zeros,ax=ax1,color='Blue')
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\3483694784.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(count_ones,ax=ax2,color='Red')

# %%
def plot_count_1(count_ones,count_zeros,title_1,title_2,subtitle):
    fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,5))
    sns.distplot(count_zeros,ax=ax1,color='Blue')
    ax1.set_title(title_1)
    sns.distplot(count_ones,ax=ax2,color='Orange')
    ax2.set_title(title_2)
    fig.suptitle(subtitle)
    plt.show()    


stops=set(stopwords.words('english'))
count_good_stops=count_good['reviews'].apply(lambda z : np.mean([len(w) for w in str(z).split()]))
count_bad_stops=count_bad['reviews'].apply(lambda z : np.mean([len(w) for w in str(z).split()]))
plot_count_1(count_good_stops,count_bad_stops,"Positive Reviews Stopwords","Negative Reviews Stopwords","Reviews Stopwords Analysis")
# Out:
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\2516594854.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(count_zeros,ax=ax1,color='Blue')
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\2516594854.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(count_ones,ax=ax2,color='Orange')

# %%
count_good_urls=count_good['reviews'].apply(lambda x: len([w for w in str(x).lower().split() if 'http' in w or 'https' in w]))
count_bad_urls=count_bad['reviews'].apply(lambda x: len([w for w in str(x).lower().split() if 'http' in w or 'https' in w]))

plot_count_1(count_good_stops,count_bad_stops,"Positive Reviews URLs","Negative Reviews URLs","Reviews URLs Analysis")
# Out:
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\2516594854.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(count_zeros,ax=ax1,color='Blue')
# C:\Users\pandh\AppData\Local\Temp\ipykernel_12500\2516594854.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(count_ones,ax=ax2,color='Orange')

# %%
from nltk.corpus import stopwords
from wordcloud import WordCloud,STOPWORDS
stop_words = stopwords.words('english')

comment_words = ''
stopwords = set(STOPWORDS)
  
# iterate through the csv file
for val in df.reviews[:10]:
      
    # typecaste each val to string
    val = str(val)
  
    # split the value
    tokens = val.split()
      
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
      
    comment_words += " ".join(tokens)+" "
    
    
    wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
  
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()

# %%
sentiment={5:"positive",4:"positive",3:"neutral",2:"negative",1:"negative"}
df["sentiment"]=df['sentiment'].map(sentiment)
df.head()
# Out:
#                                                 name   brand  \
# 0  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 1  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 2  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 3  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 4  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
#
#                                           categories  \
# 0  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 3  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 4  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#   reviews.doRecommend  reviews.numHelpful sentiment  \
# 0                True                 0.0  positive
# 1                True                 0.0  positive
# 2                True                 0.0  positive
# 3                True                 0.0  positive
# 4                True                 0.0  positive
#
#                                              reviews  \
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...
#
#                                      title reviews.username  \
# 0                                   Kindle          Adapter
# 1                                very fast           truman
# 2  Beginner tablet for our 9 year old son.            DaveZ
# 3                                  Good!!!           Shacks
# 4                Fantastic Tablet for kids        explore42
#
#                                               review
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...

# %%
from collections import Counter
def create_corpus(word):
    corpus=[]
    
    for x in df[df['sentiment']==word]['reviews'][0:2000].str.split():
        for i in x:
            corpus.append(i)
    return corpus


corpus=create_corpus('positive')
counter=Counter(corpus)
most=counter.most_common()
x=[]
y=[]
for word,count in most[:50]:
    if (word not in stops) :
        x.append(word)
        y.append(count)
sns.barplot(x=y,y=x)
# Out:
# <Axes: >

# %%
import re
#Removes Punctuations
def remove_punctuations(data):
    punct_tag=re.compile(r'[^\w\s]')
    data=punct_tag.sub(r'',data)
    return data

#Removes HTML syntaxes
def remove_html(data):
    html_tag=re.compile(r'<.*?>')
    data=html_tag.sub(r'',data)
    return data

#Removes URL data
def remove_url(data):
    url_clean= re.compile(r"https://\S+|www\.\S+")
    data=url_clean.sub(r'',data)
    return data
#Removes Emojis
def remove_emoji(data):
    emoji_clean= re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    data=emoji_clean.sub(r'',data)
    url_clean= re.compile(r"https://\S+|www\.\S+")
    data=url_clean.sub(r'',data)
    return data
df['reviews']=df['reviews'].fillna('').apply(str)
df['reviews']=df['reviews'].apply(lambda z: remove_punctuations(z))

df['reviews']=df['reviews'].apply(lambda z: remove_html(z))
df['reviews']=df['reviews'].apply(lambda z: remove_url(z))
df['reviews']=df['reviews'].apply(lambda z: remove_emoji(z))

# %%
df.head()
# Out:
#                                                 name   brand  \
# 0  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 1  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 2  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 3  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
# 4  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  Amazon
#
#                                           categories  \
# 0  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 3  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 4  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#   reviews.doRecommend  reviews.numHelpful sentiment  \
# 0                True                 0.0  positive
# 1                True                 0.0  positive
# 2                True                 0.0  positive
# 3                True                 0.0  positive
# 4                True                 0.0  positive
#
#                                              reviews  \
# 0  This product so far has not disappointed My ch...
# 1  great for beginner or experienced person Bough...
# 2  Inexpensive tablet for him to use and learn on...
# 3  Ive had my Fire HD 8 two weeks now and I love ...
# 4  I bought this for my grand daughter when she c...
#
#                                      title reviews.username  \
# 0                                   Kindle          Adapter
# 1                                very fast           truman
# 2  Beginner tablet for our 9 year old son.            DaveZ
# 3                                  Good!!!           Shacks
# 4                Fantastic Tablet for kids        explore42
#
#                                               review
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

cv = TfidfVectorizer(max_features=2500)
X = cv.fit_transform(df['reviews'] ).toarray()
#Filling null values with neutral
df['sentiment'] = df['sentiment'].fillna("neutral")
df['sentiment']
y = df['sentiment'] 
y
# Out:
# 0        positive
# 1        positive
# 2        positive
# 3        positive
# 4        positive
#            ...
# 34655     neutral
# 34656    negative
# 34657    negative
# 34658    negative
# 34659    negative
# Name: sentiment, Length: 34660, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)
model=LogisticRegression()

model.fit(X_train,y_train)

pred=model.predict(X_test)



print(f"Accuracy = {accuracy_score(y_test,pred)}")
# Out:
# Accuracy = 0.9396999422965955

# %%
from sklearn.naive_bayes import GaussianNB

classifier = GaussianNB()
classifier.fit(X_train, y_train)
pred = classifier.predict(X_test)


print(f"Accuracy = {accuracy_score(y_test,pred)}")
# Out:
# Accuracy = 0.2619734564339296

# %%
from sklearn.svm import SVC
svc_classifier = SVC(kernel = 'linear', random_state = 0)
svc_classifier.fit(X_train, y_train)
pred = svc_classifier.predict(X_test)

print(f"Accuracy = {accuracy_score(y_test,pred)}")
